# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("jsrt_metadata.csv")

# %%
m = int(data["subtlety"].astype("float").mean())

# %%
data["subtlety"].replace(np.nan,m,inplace=True)

# %%
m = int(data["size"].astype("float").mean())

# %%
data["size"].replace(np.nan,m,inplace=True)

# %%
m = data["x"].astype("float").mean()

# %%
m="{:.1f}".format(m)

# %%
data["x"].replace(np.nan,m,inplace=True)

# %%
m = data["y"].astype("float").mean()

# %%
m="{:.1f}".format(m)

# %%
data["y"].replace(np.nan,m,inplace=True)

# %%
maximum=data["position"].value_counts().idxmax()

# %%
data["position"].replace(np.nan,maximum,inplace=True)

# %%
maximum=data["diagnosis"].value_counts().idxmax()

# %%
data["diagnosis"].replace(np.nan,maximum,inplace=True)

# %%
import matplotlib as plt
from matplotlib import pyplot

# %% [markdown]
# # 1. Find the total number of patients of each disease (diagnosis) and plot in histogram.

# %%
plt.pyplot.hist(data["diagnosis"],color="blue",ec="black")
# Out:
# (array([167.,  33.,  13.,   5.,   8.,   7.,   3.,   3.,   4.,   4.]),
#  array([ 0. ,  3.1,  6.2,  9.3, 12.4, 15.5, 18.6, 21.7, 24.8, 27.9, 31. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # 2. Find the total number of patients of each disease (diagnosis) with respect to the disease state(malignant or benign) and plot in a pie chart.

# %%
w=['lung cancer','lung cancer(adenocarcinoma)','tuberculoma','granuloma','lung cancer(bronchioloalveolar cell carcinoma)','unknown','metastasis of colon cancer','inflammatory mass','pulmonary tuberculosis','lung abscess','Cryptococcosis','lung cancer(squamous cell carcinoma)','Inflammatory mass','pulmonary hematoma','susp. inflammatory mass','hamartoma','sclerosing hemangioma','lung cancer(large cell carcinoma)','susp. hamartoma','metastasis of uterine cancer','organizing pneumonia','metastasis of ovarian cancer','metastatic lung cancer','lung canceror metastasis','pneumonia','calcified granuloma','lung cancer(adenosquamous carcinoma)','lung cancer(small cell carcinoma)','susp.tuberculoma','organiging pneumonia','susp. sclerosing hemangioma','susp. lung metastasis']

plt.pyplot.pie(data["diagnosis"].value_counts(),labels=w)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0ee74af250>,
# ...
#  [Text(-0.35054586834727886, 1.042649315054996, 'lung cancer'),
#   Text(-0.647695063423749, -0.8890956668528454, 'lung cancer(adenocarcinoma)'),
#   Text(-0.17415030162497125, -1.0861269135989273, 'tuberculoma'),
#   Text(0.1325904426548767, -1.0919797500487745, 'granuloma'),
#   Text(0.33725646230925976, -1.047023437479144, 'lung cancer(bronchioloalveolar cell carcinoma)'),
#   Text(0.4799715744094368, -0.9897612276498441, 'unknown'),
#   Text(0.5780255148670865, -0.9358880831395597, 'metastasis of colon cancer'),
#   Text(0.670100048440955, -0.8723336088214358, 'inflammatory mass'),
#   Text(0.7450098066787193, -0.8092962300372698, 'pulmonary tuberculosis'),
#   Text(0.7949362888017328, -0.7603132885502714, 'lung abscess'),
#   Text(0.8325727279525352, -0.7189037854050249, 'Cryptococcosis'),
#   Text(0.8680546281712871, -0.6756338968038895, 'lung cancer(squamous cell carcinoma)'),
# ...

# %% [markdown]
# # 3. Find and plot via pia chart the total number of patients of each disease (diagnosis) with respect to the gender ( Female , Male )

# %%
temp=data.groupby(by="diagnosis")

# %%
temp = temp.get_group('lung cancer')

# %%
plt.pyplot.title('Lung Cancer')
plt.pyplot.pie(temp["gender"].value_counts(),labels=["male",'female'],explode=[0,0.2],autopct='%1.1f%%',colors=['red','blue'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0ee7366aa0>,
# ...
#  [Text(-0.011596189353831868, 1.0999388748437207, 'male'),
#   Text(0.013704465710144663, -1.299927762462053, 'female')],
#  [Text(-0.0063251941929992, 0.5999666590056658, '50.3%'),
#   Text(0.008433517360089023, -0.7999555461304941, '49.7%')])

# %%
plt.pyplot.title('lung cancer(adenocarcinoma)')
temp=data.groupby(by="diagnosis")
temp = temp.get_group('lung cancer(adenocarcinoma)')
plt.pyplot.pie(temp["gender"].value_counts(),labels=["male",'female'],autopct='%1.1f%%',colors=['red','blue'],explode=[0,0.2],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0ee73b60b0>,
# ...
#  [Text(-0.5060716130681925, 0.9766737031611724, 'male'),
#   Text(0.5980847416947964, -1.1542506841028377, 'female')],
#  [Text(-0.2760390616735595, 0.5327311108151849, '65.2%'),
#   Text(0.3680521487352594, -0.710308113294054, '34.8%')])

# %%
plt.pyplot.title('tuberculoma')
a=data.groupby(by="diagnosis")
a = a.get_group('tuberculoma')
plt.pyplot.pie(a["gender"].value_counts(),labels=["male",'female'],colors=['red','blue'],autopct='%1.1f%%',explode=[0,0.2],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0ee72059c0>,
# ...
#  [Text(-0.47727208651780745, 0.9910657674599294, 'male'),
#   Text(0.5640488295210445, -1.171259543361735, 'female')],
#  [Text(-0.26033022900971314, 0.5405813277054159, '64.3%'),
#   Text(0.34710697201295043, -0.7207751036072215, '35.7%')])

# %%
plt.pyplot.title('granuloma')
a=data.groupby(by="diagnosis")
a = a.get_group('granuloma')
plt.pyplot.pie(a["gender"].value_counts(),labels=["male",'female'],autopct='%1.1f%%',explode=[0,0.2],colors=['red','blue'],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0ee7261060>,
# ...
#  [Text(-0.7778174593052023, 0.7778174593052024, 'male'),
#   Text(0.9192388155425116, -0.9192388155425121, 'female')],
#  [Text(-0.42426406871192845, 0.4242640687119285, '75.0%'),
#   Text(0.5656854249492379, -0.5656854249492381, '25.0%')])

# %%
plt.pyplot.title('lung cancer(bronchioloalveolar cell carcinoma)')
a=data.groupby(by="diagnosis")
a = a.get_group('lung cancer(bronchioloalveolar cell carcinoma)')
plt.pyplot.pie(a["gender"].value_counts(),labels=["male",'female'],colors=['red','blue'],autopct='%1.1f%%',explode=[0,0.2],shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0ee72b87f0>,
# ...
#  [Text(-0.24477311341532162, 1.0724206837565984, 'male'),
#   Text(0.2892774345176075, -1.2674062355373321, 'female')],
#  [Text(-0.13351260731744813, 0.5849567365945082, '57.1%'),
#   Text(0.1780168827800661, -0.7799422987922043, '42.9%')])

# %%
plt.pyplot.title('unknown')
a=data.groupby(by="diagnosis")
a = a.get_group('unknown')
plt.pyplot.pie(a["gender"].value_counts(),labels=['female'],autopct='%1.1f%%',explode=[0],shadow=True,colors=["cyan"])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0ee72ebf70>],
#  [Text(-1.1, 1.3471114790620887e-16, 'female')],
#  [Text(-0.6, 7.347880794884119e-17, '100.0%')])

# %%
plt.pyplot.title('metastasis of colon cancer')
a=data.groupby(by="diagnosis")
a = a.get_group('metastasis of colon cancer')
plt.pyplot.pie(a["gender"].value_counts(),labels=['male','female'],autopct='%1.1f%%',explode=[0,0.2],shadow=True,colors=['red','blue'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0ee7136d40>,
# ...
#  [Text(-0.7778174593052023, 0.7778174593052024, 'male'),
#   Text(0.9192388155425116, -0.9192388155425121, 'female')],
#  [Text(-0.42426406871192845, 0.4242640687119285, '75.0%'),
#   Text(0.5656854249492379, -0.5656854249492381, '25.0%')])

# %%
plt.pyplot.title('inflammatory mass')
a=data.groupby(by="diagnosis")
a = a.get_group('inflammatory mass')
plt.pyplot.pie(a["gender"].value_counts(),labels=['male','female'],autopct='%1.1f%%',explode=[0,0.2],shadow=True,colors=['red','blue'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0ee7182710>,
# ...
#  [Text(6.735557395310444e-17, 1.1, 'male'),
#   Text(-2.3880612583373386e-16, -1.3, 'female')],
#  [Text(3.6739403974420595e-17, 0.6, '50.0%'),
#   Text(-1.4695761589768238e-16, -0.8, '50.0%')])

# %%
a=data.groupby(by="diagnosis")
a = a.get_group('pulmonary tuberculosis')
plt.pyplot.pie(a["gender"].value_counts(),labels=['male'],autopct='%1.1f%%',explode=[0],shadow=True,colors=['red','blue'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0ee71ddd80>],
#  [Text(-1.1, 1.3471114790620887e-16, 'male')],
#  [Text(-0.6, 7.347880794884119e-17, '100.0%')])

# %%
a=data.groupby(by="diagnosis")
a = a.get_group('lung abscess')
plt.pyplot.pie(a["gender"].value_counts(),labels=['male','female'],autopct='%1.1f%%',explode=[0,0.2],shadow=True,colors=['red','blue'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0ee7030be0>,
# ...
#  [Text(6.735557395310444e-17, 1.1, 'male'),
#   Text(-2.3880612583373386e-16, -1.3, 'female')],
#  [Text(3.6739403974420595e-17, 0.6, '50.0%'),
#   Text(-1.4695761589768238e-16, -0.8, '50.0%')])

# %%
a=data.groupby(by="diagnosis")
a = a.get_group('Cryptococcosis')
plt.pyplot.pie(a["gender"].value_counts(),labels=['female'],autopct='%1.1f%%',explode=[
    0.2],shadow=True,colors=['red','blue'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0ee70883d0>],
#  [Text(-1.3, 1.5920408388915593e-16, 'female')],
#  [Text(-0.8, 9.797174393178826e-17, '100.0%')])

# %%
a=data.groupby(by="diagnosis")
a = a.get_group('lung cancer(squamous cell carcinoma)')
plt.pyplot.pie(a["gender"].value_counts(),labels=['male'],autopct='%1.1f%%',explode=[
    0.2],shadow=True,colors=['red','blue'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0ee70b3250>],
#  [Text(-1.3, 1.5920408388915593e-16, 'male')],
#  [Text(-0.8, 9.797174393178826e-17, '100.0%')])

# %%
a=data.groupby(by="diagnosis")
a = a.get_group('Inflammatory mass')
plt.pyplot.pie(a["gender"].value_counts(),labels=['female'],autopct='%1.1f%%',explode=[0.2],shadow=True,colors=['red','blue'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0ee70fe050>],
#  [Text(-1.3, 1.5920408388915593e-16, 'female')],
#  [Text(-0.8, 9.797174393178826e-17, '100.0%')])

# %%
a=data.groupby(by="diagnosis")
a = a.get_group('pulmonary hematoma')
plt.pyplot.pie(a["gender"].value_counts(),labels=["male",'female'],autopct='%1.1f%%',explode=[0,0.2],shadow=True,colors=['red','blue'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0ee6f54e50>,
# ...
#  [Text(6.735557395310444e-17, 1.1, 'male'),
#   Text(-2.3880612583373386e-16, -1.3, 'female')],
#  [Text(3.6739403974420595e-17, 0.6, '50.0%'),
#   Text(-1.4695761589768238e-16, -0.8, '50.0%')])

# %%
a=data.groupby(by="diagnosis")
a = a.get_group('susp. inflammatory mass')
plt.pyplot.pie(a["gender"].value_counts(),labels=["male",'female'],autopct='%1.1f%%',explode=[0,0.2],shadow=True,colors=['red','blue'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0ee6fa86d0>,
# ...
#  [Text(6.735557395310444e-17, 1.1, 'male'),
#   Text(-2.3880612583373386e-16, -1.3, 'female')],
#  [Text(3.6739403974420595e-17, 0.6, '50.0%'),
#   Text(-1.4695761589768238e-16, -0.8, '50.0%')])

# %%
a=data.groupby(by="diagnosis")
a = a.get_group('hamartoma')
plt.pyplot.pie(a["gender"].value_counts(),labels=['female'],autopct='%1.1f%%',explode=[0.2],shadow=True,colors=['red','blue'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0ee6e040a0>],
#  [Text(-1.3, 1.5920408388915593e-16, 'female')],
#  [Text(-0.8, 9.797174393178826e-17, '100.0%')])

# %%
a=data.groupby(by="diagnosis")
a = a.get_group('sclerosing hemangioma')
plt.pyplot.pie(a["gender"].value_counts(),labels=['female'],autopct='%1.1f%%',explode=[0.2],shadow=True,colors=['red','blue'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0ee6e26d10>],
#  [Text(-1.3, 1.5920408388915593e-16, 'female')],
#  [Text(-0.8, 9.797174393178826e-17, '100.0%')])

# %%
a=data.groupby(by="diagnosis")
a = a.get_group('lung cancer(large cell carcinoma)')
plt.pyplot.pie(a["gender"].value_counts(),labels=["male"],autopct='%1.1f%%',explode=[0.2],shadow=True,colors=['red','blue'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0ee6e71ba0>],
#  [Text(-1.3, 1.5920408388915593e-16, 'male')],
#  [Text(-0.8, 9.797174393178826e-17, '100.0%')])

# %%
a=data.groupby(by="diagnosis")
a = a.get_group('susp. hamartoma')
plt.pyplot.pie(a["gender"].value_counts(),labels=["male"],autopct='%1.1f%%',explode=[0.2],shadow=True,colors=['red','blue'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0ee6ecc9a0>],
#  [Text(-1.3, 1.5920408388915593e-16, 'male')],
#  [Text(-0.8, 9.797174393178826e-17, '100.0%')])

# %%
a=data.groupby(by="diagnosis")
a = a.get_group('metastasis of uterine cancer')
plt.pyplot.pie(a["gender"].value_counts(),labels=['female'],autopct='%1.1f%%',explode=[0.2],shadow=True,colors=['red','blue'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0ee6ef7970>],
#  [Text(-1.3, 1.5920408388915593e-16, 'female')],
#  [Text(-0.8, 9.797174393178826e-17, '100.0%')])

# %%
a=data.groupby(by="diagnosis")
a = a.get_group('organizing pneumonia')
plt.pyplot.pie(a["gender"].value_counts(),labels=['female'],autopct='%1.1f%%',explode=[0.2],shadow=True,colors=['red','blue'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0ee6d425c0>],
#  [Text(-1.3, 1.5920408388915593e-16, 'female')],
#  [Text(-0.8, 9.797174393178826e-17, '100.0%')])

# %%
a=data.groupby(by="diagnosis")
a = a.get_group('metastasis of ovarian cancer')
plt.pyplot.pie(a["gender"].value_counts(),labels=['female'],autopct='%1.1f%%',explode=[0.2],shadow=True,colors=['red','blue'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0ee6d99630>],
#  [Text(-1.3, 1.5920408388915593e-16, 'female')],
#  [Text(-0.8, 9.797174393178826e-17, '100.0%')])

# %%
a=data.groupby(by="diagnosis")
a = a.get_group('metastatic lung cancer')
plt.pyplot.pie(a["gender"].value_counts(),labels=['female'],autopct='%1.1f%%',explode=[0.2],shadow=True,colors=['red','blue'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0ee6dec1f0>],
#  [Text(-1.3, 1.5920408388915593e-16, 'female')],
#  [Text(-0.8, 9.797174393178826e-17, '100.0%')])

# %%
a=data.groupby(by="diagnosis")
a = a.get_group('lung canceror metastasis')
plt.pyplot.pie(a["gender"].value_counts(),labels=['female'],autopct='%1.1f%%',explode=[0.2],shadow=True,colors=['red','blue'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0ee6c19540>],
#  [Text(-1.3, 1.5920408388915593e-16, 'female')],
#  [Text(-0.8, 9.797174393178826e-17, '100.0%')])

# %%
a=data.groupby(by="diagnosis")
a = a.get_group('pneumonia')
plt.pyplot.pie(a["gender"].value_counts(),labels=['female'],autopct='%1.1f%%',explode=[0.2],shadow=True,colors=['red','blue'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0ee6c74430>],
#  [Text(-1.3, 1.5920408388915593e-16, 'female')],
#  [Text(-0.8, 9.797174393178826e-17, '100.0%')])

# %%
a=data.groupby(by="diagnosis")
a = a.get_group('calcified granuloma')
plt.pyplot.pie(a["gender"].value_counts(),labels=["male"],autopct='%1.1f%%',explode=[0.2],shadow=True,colors=['red','blue'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0ee6c9efe0>],
#  [Text(-1.3, 1.5920408388915593e-16, 'male')],
#  [Text(-0.8, 9.797174393178826e-17, '100.0%')])

# %%
a=data.groupby(by="diagnosis")
a = a.get_group('lung cancer(adenosquamous carcinoma)')
plt.pyplot.pie(a["gender"].value_counts(),labels=["male"],autopct='%1.1f%%',explode=[0.2],shadow=True,colors=['red','blue'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0ee6ce5c00>],
#  [Text(-1.3, 1.5920408388915593e-16, 'male')],
#  [Text(-0.8, 9.797174393178826e-17, '100.0%')])

# %%
a=data.groupby(by="diagnosis")
a = a.get_group('lung cancer(small cell carcinoma)')
plt.pyplot.pie(a["gender"].value_counts(),labels=["male"],autopct='%1.1f%%',explode=[0.2],shadow=True,colors=['red','blue'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0ee6b3c6d0>],
#  [Text(-1.3, 1.5920408388915593e-16, 'male')],
#  [Text(-0.8, 9.797174393178826e-17, '100.0%')])

# %%
a=data.groupby(by="diagnosis")
a = a.get_group('susp.tuberculoma')
plt.pyplot.pie(a["gender"].value_counts(),labels=["male"],autopct='%1.1f%%',explode=[0.2],shadow=True,colors=['red','blue'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0ee6b6b4f0>],
#  [Text(-1.3, 1.5920408388915593e-16, 'male')],
#  [Text(-0.8, 9.797174393178826e-17, '100.0%')])

# %%
a=data.groupby(by="diagnosis")
a = a.get_group('organiging pneumonia')
plt.pyplot.pie(a["gender"].value_counts(),labels=["male"],autopct='%1.1f%%',explode=[0.2],shadow=True,colors=['red','blue'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0ee6bb9fc0>],
#  [Text(-1.3, 1.5920408388915593e-16, 'male')],
#  [Text(-0.8, 9.797174393178826e-17, '100.0%')])

# %%
a=data.groupby(by="diagnosis")
a = a.get_group('susp. sclerosing hemangioma')
plt.pyplot.pie(a["gender"].value_counts(),labels=['female'],autopct='%1.1f%%',explode=[0.2],shadow=True,colors=['red','blue'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0ee6a08ca0>],
#  [Text(-1.3, 1.5920408388915593e-16, 'female')],
#  [Text(-0.8, 9.797174393178826e-17, '100.0%')])

# %%
a=data.groupby(by="diagnosis")
a = a.get_group('susp. lung metastasis')
plt.pyplot.pie(a["gender"].value_counts(),labels=['female'],autopct='%1.1f%%',explode=[0.2],shadow=True,colors=['red','blue'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f0ee6a379a0>],
#  [Text(-1.3, 1.5920408388915593e-16, 'female')],
#  [Text(-0.8, 9.797174393178826e-17, '100.0%')])
